# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
import kagglehub

path = kagglehub.dataset_download("abdallahwagih/mall-customers-segmentation")
print(path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/abdallahwagih/mall-customers-segmentation?dataset_version_number=1...
# 100%|██████████| 1.56k/1.56k [00:00<00:00, 2.83MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/abdallahwagih/mall-customers-segmentation/versions/1

# %%
import os

files = os.listdir(path)
files
# Out:
# ['Mall_Customers.csv']

# %%
import kagglehub

path = kagglehub.dataset_download("abdallahwagih/mall-customers-segmentation")
print("Dataset path:", path)
# Out:
# Using Colab cache for faster access to the 'mall-customers-segmentation' dataset.
# Dataset path: /kaggle/input/mall-customers-segmentation

# %%
import pandas as pd

data = pd.read_csv(path + "/Mall_Customers.csv")
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
# Select only numerical features for clustering
X = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

X.head()
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)

# %%
data['Cluster'] = clusters
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.scatterplot(
    x=data['Annual Income (k$)'],
    y=data['Spending Score (1-100)'],
    hue=data['Cluster'],
    palette='tab10'
)

plt.title("Customer Segmentation using K-Means")
plt.show()

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X_scaled, clusters)
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.41664341513732767
