# %% [markdown]
# <a href="https://colab.research.google.com/github/mtalhak003/AI-ML-Deep-Learning/blob/main/3D_Simulation_of_Gradient_Based_Optimization_on_an_Innovative_Loss_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install plotly

# %%
import numpy as np
import plotly.graph_objects as go

# %%
def f(x, y):
    return x**2 + y**2 + 0.5*np.sin(3*x) + 0.3*np.sin(3*y)

# %%
def grad(x, y):
    dfdx = 2*x + 1.5*np.cos(3*x)
    dfdy = 2*y + 0.9*np.cos(3*y)
    return np.array([dfdx, dfdy])

# %%
learning_rate = 0.05
iterations = 100

x, y = 4, 4
path = []

for i in range(iterations):
    gradient = grad(x, y)
    x -= learning_rate * gradient[0]
    y -= learning_rate * gradient[1]
    path.append((x, y, f(x, y)))

path = np.array(path)

# %%
X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(X, Y)
Z = f(X, Y)

# %%
fig = go.Figure()

# Surface
fig.add_trace(go.Surface(
    x=X,
    y=Y,
    z=Z,
    colorscale='Viridis',
    opacity=0.8
))

# Gradient descent path
fig.add_trace(go.Scatter3d(
    x=path[:,0],
    y=path[:,1],
    z=path[:,2],
    mode='lines+markers',
    marker=dict(size=4, color='red'),
    line=dict(color='red', width=4),
    name="Gradient Descent Path"
))

fig.update_layout(
    title="Interactive 3D Gradient Descent Visualization",
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='f(X,Y)'
    ),
    width=900,
    height=700
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
point, = ax.plot([], [], [], 'ro', markersize=6)
trail, = ax.plot([], [], [], 'r-', linewidth=2)

def init():
    point.set_data([], [])
    point.set_3d_properties([])
    trail.set_data([], [])
    trail.set_3d_properties([])
    return point, trail

def animate(i):
    point.set_data(path[i,0], path[i,1])
    point.set_3d_properties(path[i,2])
    trail.set_data(path[:i,0], path[:i,1])
    trail.set_3d_properties(path[:i,2])
    return point, trail

ani = animation.FuncAnimation(
    fig, animate, init_func=init,
    frames=len(path), interval=100, blit=True
)

plt.show()

# %%
def f(x, y):
    return x**4 + y**4 - 2*x**2 - 2*y**2 + 0.5*np.sin(5*x)*np.sin(5*y)
